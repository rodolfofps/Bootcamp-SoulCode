# %% [markdown]
# ##**FUNDAMENTOS DE PYTHON**
#
# Escola: SoulCode Academy
#
# Curso: Bootcamp Análise de Dados - Martech - AD2
#
# Período: Semana 4
#
# Aluno: Rodolfo Felipe Pereira dos Santos

# %% [markdown]
# *   **_Lógica de Programação:_** estruturação de conceitos e regras que orientam a execução do algoritmo.
# *  **_Algoritmo:_** é a receita, ou seja, os comandos num passo-a-passo, claro e lógico que conduzem as ações para a resolução de um problema ou para atingir determinado objetivo.
# * **_Script_** é um conjunto de instruções ou comandos escritos em uma linguagem de programação específica. Geralmente, os scripts são usados para automatizar tarefas ou para definir o comportamento de um programa ou sistema. Eles são frequentemente executados interpretando linha por linha, em vez de serem compilados em um programa executável separado.
# *  **_Programa:_** implementação do algotirmo.

# %% [markdown]
# ##**Comentários e tipos de básicos de dados**

# %%
# Exemplo de comando de saída
print("Olá mundo")
print('Olá mundo!')

# %%
#Tipos de Dados

# %% [markdown]
# ![Foto 1.png](data:image/png;base64,...)

# %% [markdown]
# ## **Variáveis**

# %%
#Escrevendo dados pessoais
print(33)       #Idade  - vairável (int) - var (qualitativa nominal)
print(1.85)     #Altura   (float)              (quantitativa contínua)
print("Rodolfo")    #Nome (string)  - aspas duplas (qualitativa nominal)
print('Santos')   #Nome (string)  - aspas simples  (qualitativa nominal)
print(False)      #Tem filhos?   (booleano)  (qualitativa) (dummy/binária)
# Out:
# 33
# 1.85
# Rodolfo
# Santos
# False

# %% [markdown]
# **RESUMO**
#
# *   Os _**comentários**_ são como notas que você deixa para que você ou outra pessoa possa ler e ajuda documentar o seu código
# *   _**Comando print:**_ é uma função de saída utilizada em várias linguagens de
# programação para exibir mensagens ou valores na tela do computador.
# *   _**\n**:_ usado para criar quebras de linha em um texto
# *   Tipos de dados no Python mais usados são int, float, str, bool
# *   int e float: dados quantitativos
# *   str: dados categóricos

# %%
#Declarando variáveis
idade =  33
altura = 1.65
nome = 'Rodolfo'
sobrenome = "Santos"
filhos = False

# %%
#Imprimirna tela
print(idade)
print(altura)
print(nome)
print(sobrenome)
print(filhos)
# Out:
# 33
# 1.65
# Rodolfo
# Santos
# False

# %%
#Impressão na tela usando apenas o nome da variável
idade
altura
nome
sobrenome
# Out:
# 'Santos'

# %%
#Impressão de mais de uma  variável no mesmo print
print(idade, altura, nome, sobrenome, filhos)
# Out:
# 33 1.65 Rodolfo Santos False

# %%
#Verificando tipo de variáveis usando type e print
print(type(idade))
print(type(altura))
print(type(nome))
print(type(sobrenome))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
#Armazenamento de strings e número
nome_completo = "Rodolfo Felipe Santos"
numero_fav = "44"

# %%
#Checando variável número favorito
print(type(numero_fav))
# Out:
# <class 'str'>

# %%
#Se o número estiver entre aspas ele se transforma numa string
print(nome_completo, numero_fav)
# Out:
# Rodolfo Felipe Santos 44

# %%
#Exemplo de verificação de tipo de variável
dados = [idade,nome, altura, sobrenome]
for i in dados:
  print(type(i))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'str'>

# %%
#Pode ser que uma variável precise ser alterada, logo é importante sempre informar
#sobre qualquer alteração

# %% [markdown]
# **Resumo**
# *  **Variáveis** permitem salvar valores na memória usando um nome que atribuímos
# * Declaramos um nome no lado esquerdo do operador igual (“=”), e no lado direito, atribuir o valor que queremos salvar para usar mais tarde.
# * Como ler: Declaramos a variável "a" ao valor do "2" do tipo int
# * Como ler: Declaramos a variável "b" ao valor do "10.953" do tipo float
# * Como ler: A variável "a" recebe valor 2 do tipo int
# * Como ler: A variável "b" recebe valor 10.953 do tipo float
# * É possível usar os dois comandos print e type juntos
# * Atenção: Número pode ser string
#
# ##**Regras para nomes de variáveis**
#
# * Deve começar com uma letra (maíuscula ou minúscula) ou subcrito(_).
# * Nunca pode começar com um número.
# * Pode conter letras maiúsculas, minúsculas, números e subscrito.
# * Não pode-se utilizar como parte do nome de uma variável:
# { ( + - * / \ ; . , ?
# * Letras maiúsculas e minúsculas são diferentes:
# casa = 4
# Casa = 4\\

# %% [markdown]
# ##  **Conversão de variáveis**
# *  A conversão éuma atividade bem comum na programação. Ele permite converter dadas variáveis (desde que atendam o mesmo tipo e critérios (Ex.: Uma string que contenha apenas números para converter em "int")

# %% [markdown]
# ![Conversão IntToFloat.png](data:image/png;base64,...)

# %%
#Conversão de int para float

num_int = 10
num_float = float(num_int)  #variável num_float recebe a variável int convertida para float

# %%
#Checagem da conversão
print(type(num_int), type(num_float))
print(num_float)

# %% [markdown]
# ![Conversão IntToString.png](data:image/png;base64,...)

# %%
#Coversão de int para string

num_int = 10
num_str = str(num_int)

# %%
#Checagem da conversão de int to str
print(type(num_int), type(num_str))
print(num_str)

# %% [markdown]
# ![Conversão FloatToString.png](data:image/png;base64,...)

# %%
# Exercícios para prática
# 1)- Float to string

n1 = 44.5
print(type(n1))

n_str = str(n1) #Conversão da variável n1(float) para string
print(type(n_str))

# %% [markdown]
# ![Conversão StringToInt.png](data:image/png;base64,...)

# %%
# 2) Conversão de string to int

# FALHA NO SISTEMA:
#Conversão de str para int ()
# num_str = '10.5'
# num_int = int(num_str)

# Conversão de str para int ()
num_str = '10.5'
num_float = float(num_str) # conversão intermediária
num_int = int(num_float)

# Checando
print(type(num_str), type(num_int))
print(num_int)

# %% [markdown]
# ![Conversão StringToFloat.png](data:image/png;base64,...)

# %%
# 3) Conversão de str to float

num_float = float(num_str)
print(num_float, type(num_float))
# Out:
# 10.5 <class 'float'>

# %% [markdown]
# ##  **Operadores matemáticos**
#
# Os operadores matemáticos básicos, tais como: adição, subtração, multiplicação, divisão, exponenciação e radiciação podem ser feitos dentro do Python.
#
# ![Operadores matemáticos.png](data:image/png;base64,...)

# %%
# Adição

num1 = 5.8865
num2 = 7.85
soma = num1 + num2
print(soma)
print(f"A soma é:{soma:.3f}") #Síntaxe para definir qtd de casas decimais
# Out:
# 13.7365
# A soma é:13.736

# %%
#Subtração
v1 = 155
v2 = 2265.846
sub = v1 - v2
print(sub)
print(f"O valor da subtração é:{sub:.2f}") #usando o "f" ele andará com as casas de acordo com a qtd do valor antes do "f"
print("A subtração é:", round(sub,2))       #usando o round a qtd de casas só andará se baseando na qtd de casas após a vírgula dos valores da variável
# Out:
# -2110.846
# O valor da subtração é:-2110.85
# A subtração é: -2110.85

# %%
#Multiplicação
b1 = 3.9
multi = b1 * 14

#modos de apresentação
print(multi)
print("O valor da multiplicação é", round(multi,2))
print(f"A multiplicação é: {multi:.2f}")
# Out:
# 54.6
# O valor da multiplicação é 54.6
# A multiplicação é: 54.60

# %%
#Divisão
b1 = 3.9
divisao = b1 / 14

#modos de apresentação
print(divisao)
print("O valor da multiplicação é", round(divisao,2))
print(f"A multiplicação é: {divisao:.2f}")
# Out:
# 0.2785714285714286
# O valor da multiplicação é 0.28
# A multiplicação é: 0.28

# %% [markdown]
# ## Operador de divisão e suas derivações
# *  (//) -  Parte inteira da divisão
# *  (%)  - Resto da divisão
# *  (**) - Potenciação

# %% [markdown]
# ### Parte inteira da divisão

# %%
# Operador de divisão (Parte inteira da divisão)  "//"
idiv = 3 // 2 #As  "//" fazem com que na divisão o valor retornado seja apenas um valor inteiro. A conta daria 1,5, mas como retorna apenas o inteiro retornará 1.
print(idiv)
# Out:
# 1

# %% [markdown]
# ### Resto da divisão
# ![Exemplo de resto em Divisão-%.jpg](data:image/jpeg;base64,...)

# %%
# Operador de divisão (Resto da divisão) "%"
rdiv = 3 % 2
print(f'O resto da divisão é: {rdiv}')
print("===========================================")

# %% [markdown]
# ### Potenciação

# %%
#Potenciação "**"
pot = 3 ** 2
print(pot)
# Out:
# 9

# %%
# Melhorando a visualização dos prints f-strings

print(f'O resultado da soma de 3 + 2 é: {soma:.0f}')
print(f'O resultado da subtração de 3 -2 é: {sub:.0f}')
print(f'O resultado da multiplicação de 3 por 2 é: {multi:.2f}')
print(f'O resultado da divisão de 3 por 2 é: {divisao:.2f}')
print(f'O resultado da parte inteira da divisão de 3 por 2 é: {idiv:.2f}')
print(f'O resto da divisão de 3 por 2 é: {rdiv:.2f}')
print(f'O resultado da potenciação de 3 a 2 é: {pot:.2f}')

# %% [markdown]
# ## Operadores de comparação (booleanos)
# *  ### Operador (==) - "Igual"

# %%
#  (==)  verifica se dois valores são iguais (retorna True ou False)
# Exemplo comparando dois algarismos : 2 e 3

comp = 2 == 3  # a variável recebe a comparação dos 2 algarismos. As 2 variáveis são do mesmo tipo, porém os valores são diferentes; logo resultado será "False"
print(comp)

comp1 = 2 == 2.0  # a var comp1 recebe a comparação dos 2 algarismos. São tipos de var diferentes (2=int e 2.0=float), mas o valor é igual; logo o resultado será "True"
print(comp1)

comp2 = 'rodolfo' == "Rodolfo" #Na comparação entre strings
print(comp2)
# Out:
# False
# True
# False

# %% [markdown]
# ### Operador (!=) - "Diferente"

# %%
# (!=) verifica se dois valores são diferentes (retorna True ou False)
# Exemplo: compara se 3 (variável a) é diferente de 3.0 (variável b)

a = 4
b = 3.0
teste = a != b   # a comparação deu que as variáveis NÃO são diferentes, pois comparou os valores e não o tipo!
print(teste)
# Out:
# True

# %% [markdown]
# ### Operador (>) - "Maior" | (<) "Menor"

# %%
# faz o comparativo pra verificar se um valor é maior que o outro (retorna True ou False)

teste1 = a > b
print(f'O valor da comparação é: {teste1}')

# faz o comparativo pra verificar se um valor é maior que o outro (retorna True ou False)

teste4 = a < b
print(f'O valor da comparação é: {teste4}')
# Out:
# O valor da comparação é: True
# O valor da comparação é: False

# %% [markdown]
# ### Operador (>=) - "Maior igual" | (<=) "Menor igual"

# %%
# (>=) faz o comparativo pra verificar se um valor é maior ou igual ao outro (retorna True ou False)

teste2 = a >= b
print(f'O valor da comparação é: {teste2}')

# (<=) faz o comparativo pra verificar se um valor é menor ou igual ao outro (retorna True ou False)

teste3 = a <= b
print(f'O valor da comparação é: {teste3}')
# Out:
# O valor da comparação é: True
# O valor da comparação é: False

# %% [markdown]
# ## Operadores de atribuição
# *  ### Atribuição direta (=)

# %%
# Atribuição direta (=) -  atribui ao lado esquerdo do sinal um valor que está ao lado direito do sinal
nome = 'Rodolfo'
peso_kg = 72
altura_m = 1.85

# %% [markdown]
# * ### Atribuição de adição (+=)

# %%
# Atribuição de adição (+=); equivale a    x = x + y (equivale a uma var x que já existe recebendo ela mesma + outro valor)
#Exemplo: criação de uma variável t que receba o número inteiro 3 e depois some 1 para essa variável
# 1)-Situação de adição (+=)
t = 3
t = t+1   # Essa mesma soma poderia ser feita por (t += 1)
print(f'O resultado da atribuição de adição (t+[número]) é: {t}')

# %% [markdown]
# * ### Atribuição de subtração (-=)

# %%
# Atribuição de subtração (-=); equivale a    x = x - y (equivale a uma var x que já existe recebendo ela mesma - outro valor)
# 2)-Situação de subtração (-=)
t = 3
t -= 1   # Essa mesma subtração poderia ser feita por (t -= 1)
print(f'O resultado da atribuição de subtração (t-[número]) é: {t}')
# Out:
# O resultado da atribuição de subtração (t-[número]) é: 2

# %% [markdown]
# * ### Atribuição de multiplicação (*=)

# %%
# Atribuição de mutliplicação (*=); equivale a    x = x * y (equivale a uma var x que já existe recebendo ela mesma * outro valor)
# 3)-Situação de multiplicação (*=)
z = 3
z *= 3   # Essa mesma multiplicação poderia ser feita por (t *= [número])
print(f'O resultado da atribuição de subtração (t*[número]) é: {z}')
# Out:
# O resultado da atribuição de subtração (t*[número]) é: 9

# %% [markdown]
# * ### Atribuição de divisão (/=)

# %%
# Atribuição de divisão (/=); equivale a    x = x / y (equivale a uma var x que já existe recebendo ela mesma / outro valor)
# 4)-Situação de divisão (/=)
j = 87
j /= 3   # Essa mesma divisão poderia ser feita por (t /= [número])
print(f'O resultado da atribuição de subtração (t/[número]) é: {j}')
# Out:
# O resultado da atribuição de subtração (t/[número]) é: 29.0

# %% [markdown]
# * ### Atribuição da parte inteira da divisão (//=)

# %%
# Atribuição da parte inteira da divisão (//=) equivale a    x = x // y
# Exempl: criação de uma variável k que recebe o número 7 e depois a parte inteira da divisão por 2
k = 7
k //= 2
print(f'O resultado de k//2 é: {k}')  #Na divisão de 7 por 2, no resultado restará um inteiro (3). 2*3 = 6 e resta 1 pra completar o 7
# Out:
# O resultado de k//2 é: 3

# %% [markdown]
# * ### Atribuição do resto da divisão (%=)

# %%
# Atribuição do resto da divisão  (%=) equivale a    x = x % y
# Exemplo: crie uma variável b que receba o número 7 e depois receba o resto da divisão dela por 2
b = 7
b %= 2
print(f'O resultado de k//2 é: {b}')  # #Na divisão de 7 por 2, no resultado restará um inteiro (3). 2*3 = 6 e resta 1 pra completar o 7. Esse valor 1 será o valor retornado!
# Out:
# O resultado de k//2 é: 1

# %% [markdown]
# * ### Atribuição de potenciação (**=)

# %%
# Atribuição de potenciação  (**=) equivale a    x = x ** y
# Exemplo: crie uma variável w que receba o valor 12 e depois receba o seu quadrado
w = 12
w **= 2
print(f'O valor da variável w elevada ao quadrado é: {w}')
# Out:
# O valor da variável w elevada ao quadrado é: 144

# %% [markdown]
# ## Operadores Lógicos
# *  ### Operador (and | &)

# %%
# (and)   Retorna verdadeiro somente se TODAS as condições de uma comparação forems atendidas
#Exemplo

teste5 = 3 >= 2 and 3 != 2 and 3 < 4  #Exemplo usando a palavra "and"
print(teste5)


teste6 = (3 >= 2) & (3 != 2) & (3 < 4)   #Exemplo usando "&" - bitwise
print(teste6)

# %% [markdown]
# *  ### Operador (or)

# %%
# (or)   Retorna vertdadeiro se PELO MENOS UM dos elementos for verdadeiro

teste7 = 3 >= 2 or 3 == 2 or 3 > 4
print(teste7)

# %% [markdown]
# *  ### Operador (not)

# %%
# (not)  Inverte os valores (verdadeiro em falso ou vice-versa)
#Exemplo:

teste8 = not(teste7)
print(teste8)

teste9 = (not(3 <= 2)) & (not(3 == 2)) & (3 < 4)  # Invertendo o resultado da primeira sentença (comparação)
print(teste9)

teste10 = not((3 >= 2) & (3 != 2) & (3 < 4))   # Invertendo o resultado da comparação
print(teste10)

# %% [markdown]
# ## Operadores de identidade
# *  _(is)_ Compara se um objeto é igual ao outro

# %%
# (is) compara se um objeto é igual ao outro, levando em consideração o valor da variável e seu tipo

h = 4
p = 4
teste11 = p == h
print(f'h == p é: {teste11}')
teste12 =  p is h
print(f'h is p é: {teste12}')
print("========================================================")
m = 3
n = 3.0
teste13 = m == n
print(f'm == n é: {teste13}')  # A comparação de igualdade é True, pois os valores são os mesmos
teste14 = m is n
print(f'm is n é: {teste14}')  # Nessa verificação usando "is" o resultado é False, pois mesmo o valor sendo igual o tipo das variáveis diferem
print(type(m))
print(type(n))
print("==========================================================")
# (is not) compara se um objeto é diferente do outro em relação ao valor e o tipo
x = 3
y = 4
teste15 = x != y
print(f'x != y é: {teste15}')
teste16 = x is not y
print(f'x is not y é: {teste16}')
print("============================================================")
o = 3
s = 3.0
teste17 = o == s
print(f'o == s é: {teste17}')
teste18 = o is not s
print(f'o is not s é: {teste18}')  # O teste deu True, pois na verificação o resultado seria False, mas como é "is not" há inversão do valor transformando-o em True!
print(type(o))
print(type(s))
print("=============================================================")

# %% [markdown]
# ## Operadores de associação (in / not in)

# %%
# (in) Retorna verdadeiro se um caracter ou sequencia de caracteres for encontrado dentro de uma string
# Exemplo:
nome = 'Camila'
teste19 = 'Cami' in nome      # o valor da variável precisa conter exatamente o segmento de caracteres, pois o Python é case sensitive!!!
print(f'Camila contém Cami?: {teste19}')
print("=========================================================================================================")
# (not in) Retorna verdadeiro se um caracter ou sequencia de caracteres NÃO for encontrado dentro de uma string
teste20 = 'Cami' not in nome
print(f'Camila não contém Cami: {teste20}')

# %% [markdown]
# ## Coleta de dados do usuário _(input)_

# %%
nome = input('Informe seu nome ')   # Qualquer valor inserido no input se enquadrará como string
print(f'O nome digitado é: {nome}')
peso = int(input('Informe seu peso em kg inteiros '))    # o int é colocado no início do input já para considerar o valor inserido como int, senão seria string
print(f'{nome} tem : {peso}kg')
altura = float(input("Informe a altura, em metros"))    # o float é colocado no início do input já para considerar o valor inserido como float(valor fracionado), senão seria string
print(f'{nome} tem {peso}[kg] e {altura}m de altura')

imc = peso / altura**2
print(f'Seu imc é {imc:.1f} {nome}')

# %% [markdown]
# ## Python Básico - Strings
# *  O Python interpreta as strings se baseando em índices. No caso de consultas tais índices servem como referência na manipulação dos caracteres. Há ainda a possibilidade de manipulá-los usando a ordem inversa de leitura, percorrendo a string de trás pra frente.
#
# ![Exemplo de índices em strings.png](data:image/png;base64,...)

# %%
email = 'rodolfo@gmail.com'
# encontrando um caracter pelo índice
# Exemplo: qual é o quinto caracter dessa string?
print(f'O quinto caracter dessa string é: {email[4]}')
print("================================================")
# Exemplo: qual é o último caracter dessa string?
print(f'O último caracter dessa string é: {email[16]}')
print("=================================================")
# Exemplo: Quais são os caracteres que vem depois do segundo caracter (excluindo o segundo segundo).
# EXPLICAÇÃO: O número ordinal estará sempre um número a frente. Se desejo a continuação depois do 2º caractere(letra o), colocarei o índice [2] que representa caracteres acima do 2º

print(f'A sequência caracteres dessa string é: {email[2:]}')
print("======================================================")
# Exemplo: Quais são todos os caracteres dessa string?
print(f'A sequência todos os caracteres dessa string é: {email[:]}')
print("========================================================")
# Exemplo: buscar e imprimir todos os caracteres até o caracter de índice 4 (todos os caracteres antes do @ até o @ incluindo o @)
print(f'A sequência caracteres dessa string até o índice 4 é: {email[2:5]}')   # No python, todo argumento antes dos ":" representa de onde a varredura irá partir (inclusive)
                                                                              #, o índice entrará na varredura; a direita dos ":" será o índice até onde vou chegar
                                                                              # Se desejo que seja impresso o índice 4, preciso especificar até o 5, pois se colocar o 4,
                                                                              #ele não entrará na impressão!

# Exemplo de como acessar o último caractere da lista sem contar seu tamanho (sem usar função "len()")
print(f'O último caracter da lista é: {email[-1]}')  # O índice -1 possibilita acessar a lista de forma inversa

# %% [markdown]
# ## Métodos para Strings

# %%
# Sinal de (+) para concatenar strings
nome = 'Rodolfo'
sobre = 'Santos'
print(nome +" "+ sobre)
print("=============================")
# Converter um número em string
cpf = 12345678910  # Usualmente, CPF, Id, telefones são usados como strings, até mesmo para questão de alocação de memória e processamento
cpf = str(cpf)
print(type(cpf))

# %% [markdown]
# ## Métodos específicos para strings
# * ### **_(.captalize)_**

# %%
# Método para deixar a primeira letra de uma string maiúscula
nomem = 'casa amarela'
print(nomem)
nomem = nomem.capitalize()   #O ".captalize" serve para padronizar , por exemplo, os dados de uma coluna, uniformizando-os.
print(nomem)
print("=====================================")

# %% [markdown]
# * ### _(.casefold)_

# %%
# Deixa a string em letras minúsculas
nomem = nomem.casefold()   #O ".captalize" serve para padronizar , por exemplo, os dados de uma coluna, uniformizando-os. Tornando os dados em minúsculos
print(nomem)
print("=====================================")

# %% [markdown]
# * ### _(.count)_

# %%
# (count) -  Conta quantas vezes um caractere aparece numa string
material = 'paralelepipedo'
qtd_p = material.count('a')   # a propriedade ".count" necessita de argumento, no caso a letra que se deseja verificar, por exemplo!
print(f'A qtd de letras "P" é: {qtd_p}')
print("=====================================")

# %% [markdown]
# * ### _(.endswith)_

# %%
# (endswith) - Verifica se uma string TERMINA com um caractere ou sequência de caracteres (retorna True ou False)
email = 'rodolfo@gmail.com'
teste_end = email.endswith('com')
print(teste_end)
print("=====================================")

# %% [markdown]
# * ### _(.startswith)_

# %%
# (startswith) - Verifica se uma string COMEÇA com um caractere ou sequência de caracteres (retorna True ou False)
email = 'rodolfo@gmail.com'
teste_begin = email.startswith('rod')
print(teste_begin)
print("=====================================")

# %% [markdown]
# * ### _(.isnumeric)_

# %%
# (isnumeric) Verifica se uma string é formada por números
rg = 'd123456789'
teste_rg = rg.isnumeric() #Esse método pode servir de teste para ver conseguimos fazer a conversão de uma variável, por exemplo, no caso se não tivesse uma letra
print(teste_rg)           # seria True, seria numérico, pois teria apenas números; mas como tem uma letra que seja dá False.
print("=====================================")

# %% [markdown]
# * ### _(.isalpha)_

# %%
# (isalpha) Verifica se uma string é formada por letras (não possui argumento e retorna True ou False)
rg2 = 'doug'
teste_rg2 = rg2.isalpha()
print(teste_rg2)
print("=====================================")
# Out:
# True
# =====================================

# %% [markdown]
# * ### _(.isalnum)_

# %%
# (isalnum) Verifica se uma string é formada por letras ou números
rg3 = 'D'
teste_rg3 = rg3.isalnum()
print(teste_rg3)
print("=====================================")

# %% [markdown]
# * ### _(.split)_

# %%
# (split) Separa uma string por caracteres específicos, se não for específicado o caracter ela assume espaço como separador
dados = input('informe os valores separados por espaços ')
dados_sep = dados.split()     # De certa forma, transforma numa lista
print(dados_sep)
print("=====================================")

# %% [markdown]
# * ### _(.strip)_

# %%
# (strip) elimina caracteres indesejados de uma string, por padrão remove espaços do início e do final da string
autor = ' Rodolfo '
print(len(autor))
autor = autor.strip()
print(len(autor))
print("=====================================")
# Out:
# 9
# 7
# =====================================

# %% [markdown]
# * ### _(.replace)_

# %%
# (replace) substitui um caracter por outro
preco = 'R$ 10.50'
print(preco)
preco = preco.replace('.',',') # Substitui o "." pelo sinal de ","
print(preco)
print("=====================================================")

# %% [markdown]
# * ### _(.title)_

# %%
# (title) Coloca a primeira letra de cada palavra em maiúscula
comp = 'rodolfo felipe Pereira dos santos'
print(comp)
comp = comp.title()
print(comp)
print("======================================================")
# Out:
# rodolfo felipe Pereira dos santos
# Rodolfo Felipe Pereira Dos Santos
# ======================================================

# %% [markdown]
# * ### _(.upper)_

# %%
# (upper) Coloca todas as letras de um texto em maiúsculas
aluno = 'rodolfo'
print(aluno)
aluno = aluno.upper()
print(aluno)

# %% [markdown]
# ## Estrutura de condição - If, elif, else
#
#
# *  ### _(if)_
#
#   A instrução "if" é usada para executar um bloco de código se uma determinada condição for verdadeira. A sintaxe geral é a seguinte:

# %%
'''
if [condição]
    bloco de código a ser executado se condição for verdadeira
'''

# %%
idade = 19
if idade >= 18:
  print(f'Você é maior de idade, possui {idade} anos')
# Out:
# Você é maior de idade, possui 19 anos

# %%
idade = 18
if idade >= 18:
  print(f'Você é maior de idade, possui {idade} anos')
# Out:
# Você é maior de idade, possui 18 anos

# %%
idade = 17
if idade >= 18:
  print(f'Você é maior de idade, possui {idade} anos')

# %% [markdown]
# *  ### _(else)_
#
#   A instrução "else" é usada em conjunto com a instrução "if" e especifica um bloco de código a ser executado se a condição "if" não for verdadeira. A sintaxe geral é a seguinte:

# %%
'''
if [condição]
    bloco de código a ser executado se condição for verdadeira
else
    bloco de código a ser executado se a primeira condição não for atendida, no caso o "if"
'''

# %%
idade  = int(input('Informe sua idade: '))
if idade >= 18:
    print(f'Você é maior de idade')
else:
    print(f'Você é menor de idade')

# %% [markdown]
# *  ### _(elif)_
#
#     A instrução "elif" é uma abreviação de "else if" e permite testar múltiplas condições em sequência. Ela é usada quando há mais de duas possibilidades a serem consideradas. A sintaxe geral é a seguinte:

# %%
'''
if [condição]
    bloco de código a ser executado se condição for verdadeira
elif [condição 2]
    bloco de código a ser executado se a condição 2 for verdadeira
else
    bloco de código a ser executado se nenhuma das condições anteriores forem atendidas
'''

# %%
nota = float(input('Digite sua nota:'))
if nota >= 90:
    print("Sua nota é A.")
elif nota >= 80:
    print("Sua nota é B.")
elif nota >= 70:
    print("Sua nota é C.")
else:
    print("Sua nota é D.")
# Out:
# Digite sua nota:98
# Sua nota é A.
